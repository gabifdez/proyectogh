# %% [markdown]
# ENTREGA N°2
# JAVIERA MALDONADO/ GABRIELA FERNANDEZ/ MAXIMILIANO JAQUE/ DORYS AROCA

# %% [markdown]
# BASE DE DATOS: PARTICIPANTES FAMOSOS EN LOS REALITIES
# GABRIELA FERNANDEZ

# %%
import pandas as pd

df = pd.read_csv('/content/Narración Gráfica Tabla de datos.csv', delimiter=';') # Cambiar ';' al delimitador correcto)

df
# Out:
#      Unnamed: 0                          Nombres      Realities
# 0             1           María José Quintanilla           Rojo
# 1             2                 Leandro Martínez           Rojo
# 2             3                Dominique Gallego       Pelotón
# 3             4  María Eugenia (Kenita) Larraín        Pelotón
# 4             5                      Camila Nash       Pelotón
# ..          ...                              ...            ...
# 111         112                    Camila Campos  Tierra Brava*
# 112         113                     Uriel Romero  Tierra Brava*
# 113         114                   Azzartt Maveth  Tierra Brava*
# 114         115                 Jhonatan Mujica   Tierra Brava*
# 115         116                        Eva Gómez  Tierra Brava*
#
# [116 rows x 3 columns]

# %%
df.isnull()
# Out:
#      Unnamed: 0  Nombres  Realities
# 0         False    False      False
# 1         False    False      False
# 2         False    False      False
# 3         False    False      False
# 4         False    False      False
# ..          ...      ...        ...
# 111       False    False      False
# 112       False    False      False
# 113       False    False      False
# 114       False    False      False
# 115       False    False      False
#
# [116 rows x 3 columns]

# %%
copia=df.copy()
copia.dropna()
datos_limpieza = df.dropna(subset=['Realities'], axis=0)

# %%
datos_limpieza.fillna(method='bfill')
# Out:
#      Unnamed: 0                          Nombres      Realities
# 0             1           María José Quintanilla           Rojo
# 1             2                 Leandro Martínez           Rojo
# 2             3                Dominique Gallego       Pelotón
# 3             4  María Eugenia (Kenita) Larraín        Pelotón
# 4             5                      Camila Nash       Pelotón
# ..          ...                              ...            ...
# 111         112                    Camila Campos  Tierra Brava*
# 112         113                     Uriel Romero  Tierra Brava*
# 113         114                   Azzartt Maveth  Tierra Brava*
# 114         115                 Jhonatan Mujica   Tierra Brava*
# 115         116                        Eva Gómez  Tierra Brava*
#
# [116 rows x 3 columns]

# %% [markdown]
# BASE DE DATOS: IMPACTO EN RRSS DE GH
# DORYS AROCA

# %%
import pandas as pd

df = pd.read_csv ('/content/datos imapcto ig.csv')

df
# Out:
#    Clasificación likes y comentarios anuncio de participantes  en Instagram (Gran Hermano y Tierra Brava);;;;;;;;;;;;;
# 0   Participante; Reality ; Likes ; Comentarios ;;...
# 1              Fernando ; GH ; 1.858 ; 132 ;;;;;;;;;;
# 2                  Maite; GH ; 2.410 ; 165 ;;;;;;;;;;
# 3                  Lucas; GH ; 5.387 ; 648 ;;;;;;;;;;
# 4              Jennifer ; GH ; 2.870 ; 448 ;;;;;;;;;;
# ..                                                ...
# 64                                      ;;;;;;;;;;;;;
# 65                                      ;;;;;;;;;;;;;
# 66                                      ;;;;;;;;;;;;;
# 67                                      ;;;;;;;;;;;;;
# 68                                      ;;;;;;;;;;;;;
#
# [69 rows x 1 columns]

# %% [markdown]
# BASE DE DATOS: CARACTERISTICAS Y VARIABLES DE REALITIES CHILENOS
# JAVIERA TRINIDAD MALDONADO

# %%
import pandas as pd

df = pd.read_csv ('/content/Caracteristicas y variables de cada reality.csv', delimiter=';') # Cambiar ';' al delimitador correcto)

df
# Out:
#      año     canal                            titulo  \
# 0   2003       TVN          Rojo: Primera generación
# 1   2003  Canal 13          Protagonistas de la fama
# 2   2003  Canal 13  Conquistadores del fin del mundo
# 3   2003  Canal 13        Protagonistas de la música
# 4   2005  Canal 13                         La granja
# ..   ...       ...                               ...
# 69  2021       CHV        ¿Quién es la máscara? (II)
# 70  2022  Canal 13   MasterChef Celebrity Chile (II)
# 71  2022       CHV       ¿Quién es la máscara? (III)
# 72  2022       CHV       El discípulo del chef (III)
# 73  2023       CHV            Gran Hermano Chile (I)
#
#                         tipo horario
# 0      Competencia artística   tarde
# 1      Competencia artística   noche
# 2         Competencia física   noche
# 3      Competencia artística   noche
# 4         Competencia física   noche
# ..                       ...     ...
# 69     Competencia artística   noche
# ...

# %%
# crear dos tablas

tabla_1 = df.copy()
tabla_2 = df.copy()

#noche
tabla_1 = tabla_1.drop(tabla_1[tabla_1 ['horario']=='tarde'].index)
tabla_1
# Out:
#      año     canal                            titulo  \
# 1   2003  Canal 13          Protagonistas de la fama
# 2   2003  Canal 13  Conquistadores del fin del mundo
# 3   2003  Canal 13        Protagonistas de la música
# 4   2005  Canal 13                         La granja
# 5   2005  Canal 13                     La granja VIP
# 6   2005  Canal 13                         Granjeras
# 7   2006  Canal 13                           La casa
# 8   2006  Canal 13  Expedición Robinson, la isla VIP
# 12  2007       TVN                           Pelotón
# 14  2008       TVN                      Pelotón (II)
# 15  2008  Canal 13                        Amor ciego
# 16  2008  Canal 13                   Amor ciego (II)
# 17  2009       TVN                El juego del miedo
# 18  2009  Canal 13                              1810
# 20  2009  Canal 13                              1910
# 21  2009       TVN                     Pelotón (III)
# 22  2009       CHV                   Fiebre de baile
# ...

# %%
#tarde
tabla_2 = tabla_2.drop(tabla_2[tabla_2 ['horario']=='noche'].index)
tabla_2
# Out:
#      año     canal                          titulo                   tipo  \
# 0   2003       TVN        Rojo: Primera generación  Competencia artística
# 9   2006       TVN                 El baile en TVN  Competencia artística
# 10  2007  Canal 13                            Fama  Competencia artística
# 11  2007       TVN            El baile en TVN (II)  Competencia artística
# 13  2007       TVN           El baile en TVN (III)  Competencia artística
# 19  2009       TVN                         Calle 7     Competencia física
# 24  2010       TVN                    Calle 7 (II)     Competencia física
# 26  2010       TVN                   Calle 7 (III)     Competencia física
# 27  2010       TVN                    Calle 7 (IV)     Competencia física
# 31  2011       TVN                     Calle 7 (V)     Competencia física
# 33  2011       TVN                    Calle 7 (VI)     Competencia física
# 34  2011  Canal 13                         40 ó 20                  Citas
# ...

# %% [markdown]
# BASE DE DATOS:
# MAXIMILIANO JAQUE

# %%
import pandas as pd

df = pd.read_csv ('/content/twitter.csv')

df
# Out:
#    Clasificación reacciones en Twitter (sitios de Gran Hermano y Tierra Brava);;;;;;
# 0   Participante; Reality ; Comentarios ; Repost ;...
# 1                 Fernando ; GH ; 1 ; - ; 6 ; 1.979 ;
# 2                     Maite; GH ; 1 ; - ; 3 ; 2.247 ;
# 3                     Lucas; GH ; 4 ; - ; 2 ; 2.318 ;
# 4                 Jennifer ; GH ; 2 ; 1 ; 8 ; 2.579 ;
# 5                      Fran; GH ; 3 ; - ; 7 ; 3.465 ;
# 6                    Hans ; GH ; - ; - ; 18 ; 2.881 ;
# 7                     Jorge; GH ; 1 ; - ; 4 ; 2.618 ;
# 8                   Monica; GH ; 2 ; 1 ; 18 ; 3.393 ;
# 9                    Ariel; GH ; - ; - ; 12 ; 2.784 ;
# 10                 Alessia; GH ; - ; 2 ; 12 ; 3.656 ;
# 11                    Ruben; GH ; 1 ; 1 ; 9 ; 3.176 ;
# 12                Scarleth; GH ; 1 ; - ; 11 ; 3.163 ;
# 13                 Trinidad; GH ; 1 ; - ; 2 ; 3.966 ;
# 14                    Benja; GH ; 1 ; - ; 2 ; 2.398 ;
# 15                     Cony; GH ; 1 ; - ; 4 ; 3.082 ;
# ...
